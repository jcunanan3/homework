# %% [markdown]
# <img src="http://i.imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
#
# After reading the gushing praise for Pokemon Go you decide to download it and try it out for yourself. Yet a couple hours of play later you find yourself disappointed by the fact that you _actually_ have to move around outside.
#
# Though just a beginner programmer, you decide to make your own iteration on the genre: "Pokemon Stay". In this version players still need to move, but just from website to website. Pokemon gyms are now popular cyber-destinations, and catching pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# ---
#
# #### Package imports
#
# The `pprint` package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src=http://i.imgur.com/l5NasQj.png style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create a player. The dictionary and list variables should just be defined as empty at this point.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'udacity.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Example output:
# 
# ['amazon.com', 'ebay.com']
from pprint import pprint
player_id=1
player_name=""
time_played=0.0
player_pokemon={}
gyms_visited=[]
gym_locations=['reddit.com','amazon.com','twitter.com','linkedin.com','ebay.com','netflix.com','udacity.com','stackoverflow.com','github.com','quora.com']
gyms_visited.append(gym_locations[0]) 
gyms_visited.append(gym_locations[1]) 
print(gyms_visited)
# Out:
# ['reddit.com', 'amazon.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print the pokedex dictionary with the 3 pokemon.

# %%
# No example output... too similar to the answer!
pokedex={1:{'name':'charmander',
        'type':'fire',
        'hp':5,
        'attack':6,
        'defense':7,
        'special_attack':8,
        'special_defense':9,
        'speed':10},
        2:{'name':'bulbasaur',
        'type':'earth',
        'hp':50,
        'attack':60,
        'defense':70,
        'special_attack':80,
        'special_defense':90,
        'speed':100},
         3:{'name':'squirtle',
        'type':'water',
        'hp':500,
        'attack':600,
        'defense':700,
        'special_attack':800,
        'special_defense':900,
        'speed':1000}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1). **The values in the player's dictionary will be the variables you assigned in question 1.**
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {},
#      'time_played': 0.0}}
player_dict={1:{'gyms_visited': ['amazon.com', 'ebay.com'],
     'player_name': 'Ash',
      'player_pokemon': {},
      'time_played': 0.0}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'stackoverflow.com'` and `'github.com'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
# No example output. 
player_dict[2]={'gyms_visited': ['stackoverflow.com', 'github.com'],
      'player_name': 'Bill','player_pokemon': {},
     'time_played': 1.1}

print(player_dict)
# Out:
# {1: {'time_played': 0.0, 'gyms_visited': ['amazon.com', 'ebay.com'], 'player_name': 'Ash', 'player_pokemon': {}}, 2: {'time_played': 1.1, 'gyms_visited': ['stackoverflow.com', 'github.com'], 'player_name': 'Bill', 'player_pokemon': {}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {2: ...squirtle dictionary...},
#      'time_played': 0.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#      'player_name': 'Brock',
#      'player_pokemon': {1: ...charmander dictionary..., 3: ...bulbasaur dictionary...},
#      'time_played': 10.0}}
player_dict[1]['player_pokemon']=['squirtle']

player_dict[2]['player_pokemon']=('charmander','bulbasaur')
print(player_dict)
# Out:
# {1: {'time_played': 0.0, 'gyms_visited': ['amazon.com', 'ebay.com'], 'player_name': 'Ash', 'player_pokemon': ['squirtle']}, 2: {'time_played': 1.1, 'gyms_visited': ['stackoverflow.com', 'github.com'], 'player_name': 'Bill', 'player_pokemon': ('charmander', 'bulbasaur')}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. What gyms have players visited?
#
# ---
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
player_dict
# Out:
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#   'player_name': 'Ash',
#   'player_pokemon': 'squirtle',
#   'time_played': 0.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#   'player_name': 'Bill',
#   'player_pokemon': ('charmander', 'bulbasaur'),
#   'time_played': 1.1}}

# %%
# Example output:
#
# Ash has visited amazon.com.
# Ash has visited ebay.com.
# Ash has visited amazon.com.
# Brock has visited stackoverflow.com.
# Brock has visited github.com.
for gym in gym_locations:
    for player_key in player_dict.iterkeys():
        if gym in player_dict[player_key]["gyms_visited"]:
            print(player_dict[player_key]["player_name"]+' has visited '+gym)
# Out:
# Ash has visited amazon.com
# Ash has visited ebay.com
# Bill has visited stackoverflow.com
# Bill has visited github.com

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
# Example output:
#
# Ash's power is 57.
# 57
# Brock's power is 119.
# 119
power=0
for player_key in player_dict.iterkeys():
    for poke in player_dict[player_key]['player_pokemon']:
        
        for k in pokedex:
            
            if pokedex[k]['name']==poke:  
                
                power+=pokedex[k]['attack']+pokedex[k]['defense']
    
    print(player_dict[player_key]['player_name']+"'s power is "+ str(power))
# Out:
# Ash's power is 1300
# Bill's power is 1443

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# Now we have access to the raw base stats on all of the pokemon, scraped from the web.
#
# The provided code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# The first three lists in your pokedex list should look like so:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
import csv
def RepresentsInt(s):
    try: 
        int(s)
        return True
    except ValueError:
        return False
raw_pd = ''
#dialect=csv.quote_none
poke=[]
pokedex_file = '/Users/joaquincunanan/dropbox/GA_DSI_7_Homework_jc/project-1/pokemon/pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    pokereader=csv.reader(f, delimiter=',')
    
    for line in pokereader:
        
        newline=[]
        for k in line:
            if RepresentsInt(k):
                j=float(k)
            elif type(k)==str:
                j=k
            else:
                j=-1
            newline.append(j)
        poke.append(newline)
    print(poke)
# the pokedex string is assigned to the raw_pd variable
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0], [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0], [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0], [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0], [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0], [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0], [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0], [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0], [8.0, 'Wartortle', 'Water', 405.0, 59.0, 63.0, 80.0, 65.0, 80.0, 58.0], [9.0, 'Blastoise', 'Water', 530.0, 79.0, 83.0, 100.0, 85.0, 105.0, 78.0], [9.0, 'BlastoiseMega Blastoise', 'Water', 630.0, 79.0, 103.0, 120.0, 135.0, 115.0, 78.0], [10.0, 'Caterpie', 'Bug', 195.0, 45.0, 30.0, 35.0, 20.0, 20.0, 45.0], [11.0, 'Metapod', 'Bug', 205.0, 50.0, 20.0, 55.0, 25.0, 25.0, 30.0], [12.0, 'Butterfree', 'BugFlying', 395.0, 60.0, 45.0, 50.0, 90.0, 80.0, 70.0], [13.0, 'Weedle', 'BugPoison', 195.0, 40.0, 35.0, 30.0, 20.0, 20.0, 50.0], [14.0, 'Kakuna', 'BugPoison', 205.0, 45.0, 25.0, 50.0, 25.0, 25.0, 35.0], [15.0, 'Beedrill', 'BugPoison', 395.0, 65.0, 90.0, 40.0, 45.0, 80.0, 75.0], [15.0, 'BeedrillMega Beedrill', 'BugPoison', 495.0, 65.0, 150.0, 40.0, 15.0, 80.0, 145.0], [16.0, 'Pidgey', 'NormalFlying', 251.0, 40.0, 45.0, 40.0, 35.0, 35.0, 56.0], [17.0, 'Pidgeotto', 'NormalFlying', 349.0, 63.0, 60.0, 55.0, 50.0, 50.0, 71.0], [18.0, 'Pidgeot', 'NormalFlying', 479.0, 83.0, 80.0, 75.0, 70.0, 70.0, 101.0], [18.0, 'PidgeotMega Pidgeot', 'NormalFlying', 579.0, 83.0, 80.0, 80.0, 135.0, 80.0, 121.0], [19.0, 'Rattata', 'Normal', 253.0, 30.0, 56.0, 35.0, 25.0, 35.0, 72.0], [20.0, 'Raticate', 'Normal', 413.0, 55.0, 81.0, 60.0, 50.0, 70.0, 97.0], [21.0, 'Spearow', 'NormalFlying', 262.0, 40.0, 60.0, 30.0, 31.0, 31.0, 70.0], [22.0, 'Fearow', 'NormalFlying', 442.0, 65.0, 90.0, 65.0, 61.0, 61.0, 100.0], [23.0, 'Ekans', 'Poison', 288.0, 35.0, 60.0, 44.0, 40.0, 54.0, 55.0], [24.0, 'Arbok', 'Poison', 438.0, 60.0, 85.0, 69.0, 65.0, 79.0, 80.0], [25.0, 'Pikachu', 'Electric', 320.0, 35.0, 55.0, 40.0, 50.0, 50.0, 90.0], [26.0, 'Raichu', 'Electric', 485.0, 60.0, 90.0, 55.0, 90.0, 80.0, 110.0], [27.0, 'Sandshrew', 'Ground', 300.0, 50.0, 75.0, 85.0, 20.0, 30.0, 40.0], [28.0, 'Sandslash', 'Ground', 450.0, 75.0, 100.0, 110.0, 45.0, 55.0, 65.0], [29.0, 'Nidoran\xe2\x99\x80', 'Poison', 275.0, 55.0, 47.0, 52.0, 40.0, 40.0, 41.0], [30.0, 'Nidorina', 'Poison', 365.0, 70.0, 62.0, 67.0, 55.0, 55.0, 56.0], [31.0, 'Nidoqueen', 'PoisonGround', 505.0, 90.0, 92.0, 87.0, 75.0, 85.0, 76.0], [32.0, 'Nidoran\xe2\x99\x82', 'Poison', 273.0, 46.0, 57.0, 40.0, 40.0, 40.0, 50.0], [33.0, 'Nidorino', 'Poison', 365.0, 61.0, 72.0, 57.0, 55.0, 55.0, 65.0], [34.0, 'Nidoking', 'PoisonGround', 505.0, 81.0, 102.0, 77.0, 85.0, 75.0, 85.0], [35.0, 'Clefairy', 'Fairy', 323.0, 70.0, 45.0, 48.0, 60.0, 65.0, 35.0], [36.0, 'Clefable', 'Fairy', 483.0, 95.0, 70.0, 73.0, 95.0, 90.0, 60.0], [37.0, 'Vulpix', 'Fire', 299.0, 38.0, 41.0, 40.0, 50.0, 65.0, 65.0], [38.0, 'Ninetales', 'Fire', 505.0, 73.0, 76.0, 75.0, 81.0, 100.0, 100.0], [39.0, 'Jigglypuff', 'NormalFairy', 270.0, 115.0, 45.0, 20.0, 45.0, 25.0, 20.0], [40.0, 'Wigglytuff', 'NormalFairy', 435.0, 140.0, 70.0, 45.0, 85.0, 50.0, 45.0], [41.0, 'Zubat', 'PoisonFlying', 245.0, 40.0, 45.0, 35.0, 30.0, 40.0, 55.0], [42.0, 'Golbat', 'PoisonFlying', 455.0, 75.0, 80.0, 70.0, 65.0, 75.0, 90.0], [43.0, 'Oddish', 'GrassPoison', 320.0, 45.0, 50.0, 55.0, 75.0, 65.0, 30.0], [44.0, 'Gloom', 'GrassPoison', 395.0, 60.0, 65.0, 70.0, 85.0, 75.0, 40.0], [45.0,  ...

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %% [markdown]
# <img src="http://imgur.com/gGrau8s.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]
# Code to read in pokedex info
import csv
raw_pd = ''
#dialect=csv.quote_none
poke=[]
pokedex_file = '/Users/joaquincunanan/dropbox/GA_DSI_7_Homework_jc/project-1/pokemon/pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    pokereader=csv.reader(f, delimiter=',')
    #raw_pd = f.readline()
    poke.append(lambda line:line for line in pokereader)
    
    print(poke)
# the pokedex string is assigned to the raw_pd variable
# Out:
# [<generator object <genexpr> at 0x103a81af0>]

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
# Example output:
#
# {'Attack': 30.0,
#  'Defense': 50.0,
#  'HP': 40.0,
#  'Name': 'Voltorb',
#  'SpecialAttack': 55.0,
#  'SpecialDefense': 55.0,
#  'Speed': 100.0,
#  'Total': 330.0,
#  'Type': 'Electric'}
poke_dict={}
poke_fields=poke[0]

for p in poke:
    poke_dict_sub={}
    p_index=0
   
    for pf in poke_fields:
        if pf!='PokedexNumber':
            poke_dict_sub[pf]=p[p_index]
        p_index+=1   
    poke_dict[p[0]]=poke_dict_sub    
print(poke_dict)
# Out:
# {1.0: {'Name': 'Bulbasaur', 'SpecialAttack': 65.0, 'HP': 45.0, 'Speed': 45.0, 'Attack': 49.0, 'Defense': 49.0, 'SpecialDefense': 65.0, 'Total': 318.0, 'Type': 'GrassPoison'}, 2.0: {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}, 3.0: {'Name': 'VenusaurMega Venusaur', 'SpecialAttack': 122.0, 'HP': 80.0, 'Speed': 80.0, 'Attack': 100.0, 'Defense': 123.0, 'SpecialDefense': 120.0, 'Total': 625.0, 'Type': 'GrassPoison'}, 4.0: {'Name': 'Charmander', 'SpecialAttack': 60.0, 'HP': 39.0, 'Speed': 65.0, 'Attack': 52.0, 'Defense': 43.0, 'SpecialDefense': 50.0, 'Total': 309.0, 'Type': 'Fire'}, 5.0: {'Name': 'Charmeleon', 'SpecialAttack': 80.0, 'HP': 58.0, 'Speed': 80.0, 'Attack': 64.0, 'Defense': 58.0, 'SpecialDefense': 65.0, 'Total': 405.0, 'Type': 'Fire'}, 6.0: {'Name': 'CharizardMega Charizard Y', 'SpecialAttack': 159.0, 'HP': 78.0, 'Speed': 100.0, 'Attack': 104.0, 'Defense': 78.0, 'SpecialDefense': 115.0, 'Total': 634.0, 'Type': 'FireFlying'}, 7.0: {'Name': 'Squirtle', 'SpecialAttack': 50.0, 'HP': 44.0, 'Speed': 43.0, 'Attack': 48.0, 'Defense': 65.0, 'SpecialDefense': 64.0, 'Total': 314.0, 'Type': 'Water'}, 8.0: {'Name': 'Wartortle', 'SpecialAttack': 65.0, 'HP': 59.0, 'Speed': 58.0, 'Attack': 63.0, 'Defense': 80.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'Water'}, 9.0: {'Name': 'BlastoiseMega Blastoise', 'SpecialAttack': 135.0, 'HP': 79.0, 'Speed': 78.0, 'Attack': 103.0, 'Defense': 120.0, 'SpecialDefense': 115.0, 'Total': 630.0, 'Type': 'Water'}, 10.0: {'Name': 'Caterpie', 'SpecialAttack': 20.0, 'HP': 45.0, 'Speed': 45.0, 'Attack': 30.0, 'Defense': 35.0, 'SpecialDefense': 20.0, 'Total': 195.0, 'Type': 'Bug'}, 11.0: {'Name': 'Metapod', 'SpecialAttack': 25.0, 'HP': 50.0, 'Speed': 30.0, 'Attack': 20.0, 'Defense': 55.0, 'SpecialDefense': 25.0, 'Total': 205.0, 'Type': 'Bug'}, 12.0: {'Name': 'Butterfree', 'SpecialAttack': 90.0, 'HP': 60.0, 'Speed': 70.0, 'Attack': 45.0, 'Defense': 50.0, 'SpecialDefense': 80.0, 'Total': 395.0, 'Type': 'BugFlying'}, 13.0: {'Name': 'Weedle', 'SpecialAttack': 20.0, 'HP': 40.0, 'Speed': 50.0, 'Attack': 35.0, 'Defense': 30.0, 'SpecialDefense': 20.0, 'Total': 195.0, 'Type': 'BugPoison'}, 14.0: {'Name': 'Kakuna', 'SpecialAttack': 25.0, 'HP': 45.0, 'Speed': 35.0, 'Attack': 25.0, 'Defense': 50.0, 'SpecialDefense': 25.0, 'Total': 205.0, 'Type': 'BugPoison'}, 15.0: {'Name': 'BeedrillMega Beedrill', 'SpecialAttack': 15.0, 'HP': 65.0, 'Speed': 145.0, 'Attack': 150.0, 'Defense': 40.0, 'SpecialDefense': 80.0, 'Total': 495.0, 'Type': 'BugPoison'}, 16.0: {'Name': 'Pidgey', 'SpecialAttack': 35.0, 'HP': 40.0, 'Speed': 56.0, 'Attack': 45.0, 'Defense': 40.0, 'SpecialDefense': 35.0, 'Total': 251.0, 'Type': 'NormalFlying'}, 17.0: {'Name': 'Pidgeotto', 'SpecialAttack': 50.0, 'HP': 63.0, 'Speed': 71.0, 'Attack': 60.0, 'Defense': 55.0, 'SpecialDefense': 50.0, 'Total': 349.0, 'Type': 'NormalFlying'}, 18.0: {'Name': 'PidgeotMega Pidgeot', 'SpecialAttack': 135.0, 'HP': 83.0, 'Speed': 121.0, 'Attack': 80.0, 'Defense': 80.0, 'SpecialDefense': 80.0, 'Total': 579.0, 'Type': 'NormalFlying'}, 19.0: {'Name': 'Rattata', 'SpecialAttack': 25.0, 'HP': 30.0, 'Speed': 72.0, 'Attack': 56.0, 'Defense': 35.0, 'SpecialDefense': 35.0, 'Total': 253.0, 'Type': 'Normal'}, 20.0: {'Name': 'Raticate', 'SpecialAttack': 50.0, 'HP': 55.0, 'Speed': 97.0, 'Attack': 81.0, 'Defense': 60.0, 'SpecialDefense': 70.0, 'Total': 413.0, 'Type': 'Normal'}, 21.0: {'Name': 'Spearow', 'SpecialAttack': 31.0, 'HP': 40.0, 'Speed': 70.0, 'Attack': 60.0, 'Defense': 30.0, 'SpecialDefense': 31.0, 'Total': 262.0, 'Type': 'NormalFlying'}, 22.0: {'Name': 'Fearow', 'SpecialAttack': 61.0, 'HP': 65.0, 'Speed': 100.0, 'Attack': 90.0, 'Defense': 65.0, 'SpecialDefense': 61.0, 'Total': 442.0, 'Type': 'NormalFlying'}, 23.0: {'Name': 'Ekans', 'SpecialAttack': 40.0, 'HP': 35.0, 'Speed': 55.0, 'Attack': 60.0, 'Defense': 44.0, 'SpecialDefense': 54.0, 'Total': 288.0, 'Type': 'Poi ...

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
def filtered_pokedex(poke_ref,filter_dict):
    result=[]
    
    for p,value in poke_ref.iteritems():
        result_count=0       
        for f,v in filter_dict.iteritems():            
            if RepresentsInt(v)==False:
                if value[f]==v:
                    result_count+=1
            elif value[f]>=v:
                result_count+=1
        if result_count==len(filter_dict):
            result.append(poke_ref[p])
            print(poke_ref[p])
    return result
filter_options = {
    'Attack':   25,
    'Defense':  30,
    'Type':     'Electric'
}

print(filtered_pokedex(poke_dict,filter_options))
# Out:
# {'Name': 'Pikachu', 'SpecialAttack': 50.0, 'HP': 35.0, 'Speed': 90.0, 'Attack': 55.0, 'Defense': 40.0, 'SpecialDefense': 50.0, 'Total': 320.0, 'Type': 'Electric'}
# {'Name': 'Raichu', 'SpecialAttack': 90.0, 'HP': 60.0, 'Speed': 110.0, 'Attack': 90.0, 'Defense': 55.0, 'SpecialDefense': 80.0, 'Total': 485.0, 'Type': 'Electric'}
# {'Name': 'Voltorb', 'SpecialAttack': 55.0, 'HP': 40.0, 'Speed': 100.0, 'Attack': 30.0, 'Defense': 50.0, 'SpecialDefense': 55.0, 'Total': 330.0, 'Type': 'Electric'}
# {'Name': 'Electrode', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 140.0, 'Attack': 50.0, 'Defense': 70.0, 'SpecialDefense': 80.0, 'Total': 480.0, 'Type': 'Electric'}
# {'Name': 'Electabuzz', 'SpecialAttack': 95.0, 'HP': 65.0, 'Speed': 105.0, 'Attack': 83.0, 'Defense': 57.0, 'SpecialDefense': 85.0, 'Total': 490.0, 'Type': 'Electric'}
# {'Name': 'Jolteon', 'SpecialAttack': 110.0, 'HP': 65.0, 'Speed': 130.0, 'Attack': 65.0, 'Defense': 60.0, 'SpecialDefense': 95.0, 'Total': 525.0, 'Type': 'Electric'}
# {'Name': 'Mareep', 'SpecialAttack': 65.0, 'HP': 55.0, 'Speed': 35.0, 'Attack': 40.0, 'Defense': 40.0, 'SpecialDefense': 45.0, 'Total': 280.0, 'Type': 'Electric'}
# {'Name': 'Flaaffy', 'SpecialAttack': 80.0, 'HP': 70.0, 'Speed': 45.0, 'Attack': 55.0, 'Defense': 55.0, 'SpecialDefense': 60.0, 'Total': 365.0, 'Type': 'Electric'}
# {'Name': 'Elekid', 'SpecialAttack': 65.0, 'HP': 45.0, 'Speed': 95.0, 'Attack': 63.0, 'Defense': 37.0, 'SpecialDefense': 55.0, 'Total': 360.0, 'Type': 'Electric'}
# {'Name': 'Raikou', 'SpecialAttack': 115.0, 'HP': 90.0, 'Speed': 115.0, 'Attack': 85.0, 'Defense': 75.0, 'SpecialDefense': 100.0, 'Total': 580.0, 'Type': 'Electric'}
# {'Name': 'Electrike', 'SpecialAttack': 65.0, 'HP': 40.0, 'Speed': 65.0, 'Attack': 45.0, 'Defense': 40.0, 'SpecialDefense': 40.0, 'Total': 295.0, 'Type': 'Electric'}
# {'Name': 'ManectricMega Manectric', 'SpecialAttack': 135.0, 'HP': 70.0, 'Speed': 135.0, 'Attack': 75.0, 'Defense': 80.0, 'SpecialDefense': 80.0, 'Total': 575.0, 'Type': 'Electric'}
# {'Name': 'Plusle', 'SpecialAttack': 85.0, 'HP': 60.0, 'Speed': 95.0, 'Attack': 50.0, 'Defense': 40.0, 'SpecialDefense': 75.0, 'Total': 405.0, 'Type': 'Electric'}
# {'Name': 'Minun', 'SpecialAttack': 75.0, 'HP': 60.0, 'Speed': 95.0, 'Attack': 40.0, 'Defense': 50.0, 'SpecialDefense': 85.0, 'Total': 405.0, 'Type': 'Electric'}
# {'Name': 'Shinx', 'SpecialAttack': 40.0, 'HP': 45.0, 'Speed': 45.0, 'Attack': 65.0, 'Defense': 34.0, 'SpecialDefense': 34.0, 'Total': 263.0, 'Type': 'Electric'}
# {'Name': 'Luxio', 'SpecialAttack': 60.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 85.0, 'Defense': 49.0, 'SpecialDefense': 49.0, 'Total': 363.0, 'Type': 'Electric'}
# {'Name': 'Luxray', 'SpecialAttack': 95.0, 'HP': 80.0, 'Speed': 70.0, 'Attack': 120.0, 'Defense': 79.0, 'SpecialDefense': 79.0, 'Total': 523.0, 'Type': 'Electric'}
# {'Name': 'Pachirisu', 'SpecialAttack': 45.0, 'HP': 60.0, 'Speed': 95.0, 'Attack': 45.0, 'Defense': 70.0, 'SpecialDefense': 90.0, 'Total': 405.0, 'Type': 'Electric'}
# {'Name': 'Electivire', 'SpecialAttack': 95.0, 'HP': 75.0, 'Speed': 95.0, 'Attack': 123.0, 'Defense': 67.0, 'SpecialDefense': 85.0, 'Total': 540.0, 'Type': 'Electric'}
# {'Name': 'Blitzle', 'SpecialAttack': 50.0, 'HP': 45.0, 'Speed': 76.0, 'Attack': 60.0, 'Defense': 32.0, 'SpecialDefense': 32.0, 'Total': 295.0, 'Type': 'Electric'}
# {'Name': 'Zebstrika', 'SpecialAttack': 80.0, 'HP': 75.0, 'Speed': 116.0, 'Attack': 100.0, 'Defense': 63.0, 'SpecialDefense': 63.0, 'Total': 497.0, 'Type': 'Electric'}
# {'Name': 'Tynamo', 'SpecialAttack': 45.0, 'HP': 35.0, 'Speed': 60.0, 'Attack': 55.0, 'Defense': 40.0, 'SpecialDefense': 40.0, 'Total': 275.0, 'Type': 'Electric'}
# {'Name': 'Eelektrik', 'SpecialAttack': 75.0, 'HP': 65.0, 'Speed': 40.0, 'Attack': 85.0, 'Defense': 70.0, 'SpecialDefense': 70.0, 'Total': 405.0, 'Type': 'Electric'}
# {'Name': 'Eelektross', 'SpecialAttack': 105.0, 'HP': 85.0, 'Speed': 50.0, 'Attack': 115.0, 'Defense': 80.0, 'SpecialDefense': 80.0, 'Total': 515.0, 'Type': 'Electric'}
# [{'Name': 'Pikachu', 'SpecialAttack': 50.0, 'HP': 35.0, 'Speed': 90.0, 'Attack': 55.0, 'Defense': 40.0, 'SpecialDefense': 50.0, 'Total': 320.0, 'Type': 'Electric'}, {'Name': 'Raichu', 'SpecialAttack': 90.0, 'HP': 60.0, 'Speed': 110.0, 'Attack': 90.0, 'Defense': 55.0, 'SpecialDefense': 80.0, 'Total': 485.0, 'Type': 'Electric'}, {'Name': 'Voltorb', 'SpecialAttack': 55.0, 'HP': 40.0, 'Speed': 100.0, 'Attack': 30.0, 'Defense': 50.0, 'SpecialDefense': 55.0, 'Total': 330.0, 'Type': 'Electric'}, {'Name': 'Electrode', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 140.0, 'Attack': 50.0, 'Defense': 70.0, 'SpecialDefense': 80.0, 'Total': 480.0, 'Type': 'Electric'}, {'Name': 'Electabuzz', 'SpecialAttack': 95.0, 'HP': 65.0, 'Speed': 105.0, 'Attack': 83.0, 'Defense': 57.0, 'SpecialDefense': 85.0, 'Total': 490.0, 'Type': 'Electric'}, {'Name': 'Jolteon', 'SpecialAttack': 110.0, 'HP': 65.0, 'Speed': 130.0, 'Attack': 65.0, 'Defense': 60.0, 'SpecialDefense': 95.0, 'Total': 525.0, 'Type': 'Electric'}, {'Name': 'Mareep', 'SpecialAttack': 65.0, 'HP': 55.0, 'Speed': 35.0, 'Attack': 40.0, 'Defense': 40.0, 'SpecialDefense': 45.0, 'Total': 280.0, 'Type': 'Electric'}, {'Name': 'Flaaffy', 'SpecialAttack': 80.0, 'HP': 70.0, 'Speed': 45.0, 'Attack': 55.0, 'Defense': 55.0, 'SpecialDefense': 60.0, 'Total': 365.0, 'Type': 'Electric'}, {'Name': 'Elekid', 'SpecialAttack': 65.0, 'HP': 45.0, 'Speed': 95.0, 'Attack': 63.0, 'Defense': 37.0, 'SpecialDefense': 55.0, 'Total': 360.0, 'Type': 'Electric'}, {'Name': 'Raikou', 'SpecialAttack': 115.0, 'HP': 90.0, 'Speed': 115.0, 'Attack': 85.0, 'Defense': 75.0, 'SpecialDefense': 100.0, 'Total': 580.0, 'Type': 'Electric'}, {'Name': 'Electrike', 'SpecialAttack': 65.0, 'HP': 40.0, 'Speed': 65.0, 'Attack': 45.0, 'Defense': 40.0, 'SpecialDefense': 40.0, 'Total': 295.0, 'Type': 'Electric'}, {'Name': 'ManectricMega Manectric', 'SpecialAttack': 135.0, 'HP': 70.0, 'Speed': 135.0, 'Attack': 75.0, 'Defense': 80.0, 'SpecialDefense': 80.0, 'Total': 575.0, 'Type': 'Electric'}, {'Name': 'Plusle', 'SpecialAttack': 85.0, 'HP': 60.0, 'Speed': 95.0, 'Attack': 50.0, 'Defense': 40.0, 'SpecialDefense': 75.0, 'Total': 405.0, 'Type': 'Electric'}, {'Name': 'Minun', 'SpecialAttack': 75.0, 'HP': 60.0, 'Speed': 95.0, 'Attack': 40.0, 'Defense': 50.0, 'SpecialDefense': 85.0, 'Total': 405.0, 'Type': 'Electric'}, {'Name': 'Shinx', 'SpecialAttack': 40.0, 'HP': 45.0, 'Speed': 45.0, 'Attack': 65.0, 'Defense': 34.0, 'SpecialDefense': 34.0, 'Total': 263.0, 'Type': 'Electric'}, {'Name': 'Luxio', 'SpecialAttack': 60.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 85.0, 'Defense': 49.0, 'SpecialDefense': 49.0, 'Total': 363.0, 'Type': 'Electric'}, {'Name': 'Luxray', 'SpecialAttack': 95.0, 'HP': 80.0, 'Speed': 70.0, 'Attack': 120.0, 'Defense': 79.0, 'SpecialDefense': 79.0, 'Total': 523.0, 'Type': 'Electric'}, {'Name': 'Pachirisu', 'SpecialAttack': 45.0, 'HP': 60.0, 'Speed': 95.0, 'Attack': 45.0, 'Defense': 70.0, 'SpecialDefense': 90.0, 'Total': 405.0, 'Type': 'Electric'}, {'Name': 'Electivire', 'SpecialAttack': 95.0, 'HP': 75.0, 'Speed': 95.0, 'Attack': 123.0, 'Defense': 67.0, 'SpecialDefense': 85.0, 'Total': 540.0, 'Type': 'Electric'}, {'Name': 'Blitzle', 'SpecialAttack': 50.0, 'HP': 45.0, 'Speed': 76.0, 'Attack': 60.0, 'Defense': 32.0, 'SpecialDefense': 32.0, 'Total': 295.0, 'Type': 'Electric'}, {'Name': 'Zebstrika', 'SpecialAttack': 80.0, 'HP': 75.0, 'Speed': 116.0, 'Attack': 100.0, 'Defense': 63.0, 'SpecialDefense': 63.0, 'Total': 497.0, 'Type': 'Electric'}, {'Name': 'Tynamo', 'SpecialAttack': 45.0, 'HP': 35.0, 'Speed': 60.0, 'Attack': 55.0, 'Defense': 40.0, 'SpecialDefense': 40.0, 'Total': 275.0, 'Type': 'Electric'}, {'Name': 'Eelektrik', 'SpecialAttack': 75.0, 'HP': 65.0, 'Speed': 40.0, 'Attack': 85.0, 'Defense': 70.0, 'SpecialDefense': 70.0, 'Total': 405.0, 'Type': 'Electric'}, {'Name': 'Eelektross', 'SpecialAttack': 105.0, 'HP': 85.0, 'Speed': 50.0, 'Attack': 115.0, 'Defense': 80.0, 'SpecialDefense': 80.0, 'Total': 515.0, 'Type': 'Electric'}]
